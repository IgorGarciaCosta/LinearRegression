# %%
import keras
import numpy as np
import pandas as pd
#import matplotlib as plt
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('drive/MyDrive/Colab Notebooks/LinearRegression/IowaHousingPrices.csv')

# %%
squareFeet = df[['SquareFeet']].values
salePrice = df[['SalePrice']].values

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(1, input_shape=(1,)))
model.compile(keras.optimizers.Adam(lr=1), 'mean_squared_error')#input algorithm thats going to minimize erros

model.fit(squareFeet, salePrice, epochs = 30, batch_size = 10)

# %%
df.plot(kind='scatter', x='SquareFeet', y='SalePrice', title='Housing prices and square footage of iowa homes')
y_pred = model.predict(squareFeet)
plt.plot(squareFeet, y_pred, color='red')

# %%
newSF = 2000
print(model.predict([newSF]))
# Out:
# [[234933.69]]
